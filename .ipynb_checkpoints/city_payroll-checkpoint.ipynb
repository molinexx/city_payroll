# %% [markdown]
# [Source of the data]
# (https://data.cityofnewyork.us/City-Government/Citywide-Payroll-Data-Fiscal-Year-/k397-673e)

# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# all_2020 - data with all employees in 2020 fiskal year.
#
# all_active_2020 - employess in 2020, with Active status.
#
# annual_2020 -  employees with annual Pay Basis and Active status in 2020.
#
# dep_of_edu - employees with annual Pay Bais and Active status in 2020 working for dep of Education.

# %%
path = r"C:\Users\Maryla\Desktop\MY_PROJECTS\excel files\Citywide_Payroll_Data__Fiscal_Year_.csv"
dt = pd.read_csv(path)
dt.head()
# Out:
# C:\Users\Maryla\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Fiscal Year  Payroll Number                     Agency Name  Last Name  \
# 0         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT    BEREZIN
# 1         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT     GEAGER
# 2         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT     RAMANI
# 3         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT      ROTTA
# 4         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT  WILSON II
#
#   First Name Mid Init Agency Start Date Work Location Borough  \
# 0    MIKHAIL      NaN        08/10/2015              BROOKLYN
# 1   VERONICA        M        09/12/2016              BROOKLYN
# 2   SHRADDHA      NaN        02/22/2016              BROOKLYN
# ...

# %%
dt.columns
# Out:
# Index(['Fiscal Year', 'Payroll Number', 'Agency Name', 'Last Name',
#        'First Name', 'Mid Init', 'Agency Start Date', 'Work Location Borough',
#        'Title Description', 'Leave Status as of June 30', 'Base Salary',
#        'Pay Basis', 'Regular Hours', 'Regular Gross Paid', 'OT Hours',
#        'Total OT Paid', 'Total Other Pay'],
#       dtype='object')

# %%
dt['Fiscal Year'].unique()
# Out:
# array([2020, 2016, 2015, 2014, 2017, 2018, 2019], dtype=int64)

# %% [markdown]
# ## For this analis I want to include only data for 2020

# %%
all_2020 = dt[dt["Fiscal Year"] == 2020]
all_2020.head(3)
# Out:
#    Fiscal Year  Payroll Number                     Agency Name Last Name  \
# 0         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT   BEREZIN
# 1         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT    GEAGER
# 2         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT    RAMANI
#
#   First Name Mid Init Agency Start Date Work Location Borough  \
# 0    MIKHAIL      NaN        08/10/2015              BROOKLYN
# 1   VERONICA        M        09/12/2016              BROOKLYN
# 2   SHRADDHA      NaN        02/22/2016              BROOKLYN
#
#                 Title Description Leave Status as of June 30  Base Salary  \
# 0  EMERGENCY PREPAREDNESS MANAGER                     ACTIVE      86005.0
# 1  EMERGENCY PREPAREDNESS MANAGER                     ACTIVE      86005.0
# 2  EMERGENCY PREPAREDNESS MANAGER                     ACTIVE      86005.0
#
#    Pay Basis  Regular Hours  Regular Gross Paid  OT Hours  Total OT Paid  \
# ...

# %%
all_2020.corr()
# Out:
#                     Fiscal Year  Payroll Number  Base Salary  Regular Hours  \
# Fiscal Year                 NaN             NaN          NaN            NaN
# Payroll Number              NaN        1.000000    -0.142726      -0.479778
# Base Salary                 NaN       -0.142726     1.000000       0.327461
# Regular Hours               NaN       -0.479778     0.327461       1.000000
# Regular Gross Paid          NaN       -0.127927     0.830542       0.455837
# OT Hours                    NaN       -0.422975     0.198147       0.598780
# Total OT Paid               NaN       -0.347407     0.202970       0.546972
# Total Other Pay             NaN       -0.155014     0.541370       0.229396
#
#                     Regular Gross Paid  OT Hours  Total OT Paid  \
# Fiscal Year                        NaN       NaN            NaN
# Payroll Number               -0.127927 -0.422975      -0.347407
# Base Salary                   0.830542  0.198147       0.202970
# ...

# %% [markdown]
#  There is a strong corelation between Base Salary and Regular Gross Paid. It should be stronger, but I think this stat is disrupted by the fact that some worker's base salary is set by daily or hourly. The correlation might be stronger within per Annum group.
#
#  There is also some indication that full time workers might have more OT hours = corelation is almost .60 Later on I will separate data for those woring based on annual basis and per hour.

# %%
all_2020.shape
# Out:
# (590210, 17)

# %%
all_2020['Leave Status as of June 30'].value_counts()
# Out:
# ACTIVE                 482955
# CEASED                  94357
# ON LEAVE                 6997
# SEASONAL                 5021
# ON SEPARATION LEAVE       880
# Name: Leave Status as of June 30, dtype: int64

# %%
all_2020[(all_2020["Regular Gross Paid"] <0)& (all_2020["Leave Status as of June 30"]=="ACTIVE")].head(10)
# Out:
#         Fiscal Year  Payroll Number                  Agency Name  \
# 63055          2020            56.0            POLICE DEPARTMENT
# 63749          2020            56.0            POLICE DEPARTMENT
# 64237          2020            56.0            POLICE DEPARTMENT
# 65153          2020            56.0            POLICE DEPARTMENT
# 84380          2020            57.0              FIRE DEPARTMENT
# 93097          2020            67.0    ADMIN FOR CHILDREN'S SVCS
# 107440         2020            69.0  HRA/DEPT OF SOCIAL SERVICES
# 123270         2020            72.0     DEPARTMENT OF CORRECTION
# 129388         2020           210.0         PUBLIC SERVICE CORPS
# 129389         2020           210.0         PUBLIC SERVICE CORPS
#
#            Last Name  First Name Mid Init Agency Start Date  \
# 63055        LAPSLEY  STARSHEEMA        S        01/09/2013
# 63749          CADET     RICHEDA        A        01/09/2006
# 64237      SCHROEHER       KEITH        J        07/05/2017
# ...

# %% [markdown]
# ### To obtain more acurate information I will only include  active workers whose gross salary was not zero.

# %%
all_active_2020 = all_2020[(all_2020["Leave Status as of June 30"] == "ACTIVE") & (all_2020["Regular Gross Paid"] >0)]

# %%
all_active_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 477228 entries, 0 to 585777
# Data columns (total 17 columns):
# Fiscal Year                   477228 non-null int64
# Payroll Number                477228 non-null float64
# Agency Name                   477228 non-null object
# Last Name                     476935 non-null object
# First Name                    476932 non-null object
# Mid Init                      281662 non-null object
# Agency Start Date             477187 non-null object
# Work Location Borough         477226 non-null object
# Title Description             477225 non-null object
# Leave Status as of June 30    477228 non-null object
# Base Salary                   477228 non-null float64
# Pay Basis                     477228 non-null object
# Regular Hours                 477228 non-null float64
# Regular Gross Paid            477228 non-null float64
# OT Hours                      477228 non-null float64
# ...

# %%
all_active_2020.isnull().sum()
# Out:
# Fiscal Year                        0
# Payroll Number                     0
# Agency Name                        0
# Last Name                        293
# First Name                       296
# Mid Init                      195566
# Agency Start Date                 41
# Work Location Borough              2
# Title Description                  3
# Leave Status as of June 30         0
# Base Salary                        0
# Pay Basis                          0
# Regular Hours                      0
# Regular Gross Paid                 0
# OT Hours                           0
# Total OT Paid                      0
# Total Other Pay                    0
# dtype: int64

# %% [markdown]
# Looks like first and last names are missing in 293 cases. That  should not affect the data, but anyway I want to check why.
#
# Agency start date mising in 41 instances, but it is also should not be a concern.
#
# Tite description is missing in 3 entries, maybe we can check if those pepople worked in previous years and replace nan.
#
# Also work location is missing in 2 cases.

# %%
all_active_2020[all_active_2020["Last Name"].isnull()].tail(5)
# Out:
#         Fiscal Year  Payroll Number                     Agency Name Last Name  \
# 533907         2020           906.0  DISTRICT ATTORNEY-SPECIAL NARC       NaN
# 533908         2020           906.0  DISTRICT ATTORNEY-SPECIAL NARC       NaN
# 533913         2020           906.0  DISTRICT ATTORNEY-SPECIAL NARC       NaN
# 533915         2020           906.0  DISTRICT ATTORNEY-SPECIAL NARC       NaN
# 534028         2020           906.0  DISTRICT ATTORNEY-SPECIAL NARC       NaN
#
#        First Name Mid Init Agency Start Date Work Location Borough  \
# 533907        NaN      NaN        06/11/2018             MANHATTAN
# 533908        NaN      NaN        09/04/2018             MANHATTAN
# 533913        NaN      NaN        04/01/2019             MANHATTAN
# 533915        NaN      NaN        04/01/2019             MANHATTAN
# 534028        NaN      NaN        06/08/2020             MANHATTAN
#
#                                         Title Description  \
# ...

# %% [markdown]
# It seems like all people with missing names are working for Distric Attorney, and they names were most likey omitted on purpose :
#  >" data for some agencies (specifically NYC Police Department (NYPD) and the District Attorneys’ Offices (Manhattan, Kings, Queens, Richmond, Bronx, and Special Narcotics)) have been redacted since they are exempt from disclosure pursuant to the Freedom of Information Law, POL § 87(2)(f), on the ground that disclosure of the information could endanger the life and safety of the public servants listed thereon."

# %%
all_active_2020[all_active_2020["Title Description"].isnull()]
# Out:
#         Fiscal Year  Payroll Number                     Agency Name Last Name  \
# 274009         2020           464.0  COMMUNITY COLLEGE (QUEENSBORO)     GREEN
# 274110         2020           464.0  COMMUNITY COLLEGE (QUEENSBORO)   D'AMATO
# 319029         2020           745.0   DEPT OF ED HRLY SUPPORT STAFF     ORTIZ
#
#        First Name Mid Init Agency Start Date Work Location Borough  \
# 274009      BRUCE        S        11/01/2005                QUEENS
# 274110    JEFFREY        A        10/09/2017                QUEENS
# 319029          A      NaN        12/31/1999             MANHATTAN
#
#        Title Description Leave Status as of June 30  Base Salary  Pay Basis  \
# 274009               NaN                     ACTIVE     67016.00  per Annum
# 274110               NaN                     ACTIVE     64158.00  per Annum
# 319029               NaN                     ACTIVE        16.52   per Hour
#
#         Regular Hours  Regular Gross Paid  OT Hours  Total OT Paid  \
# ...

# %% [markdown]
# I want to find out their titles by doing reserach in oryginal data set, maybe previous years data have this information:

# %%
dt[(dt["Last Name"]=="GREEN") & (dt["First Name"]=="BRUCE") & (dt["Agency Name"] =="COMMUNITY COLLEGE (QUEENSBORO)")]
# Out:
#          Fiscal Year  Payroll Number                     Agency Name  \
# 274009          2020           464.0  COMMUNITY COLLEGE (QUEENSBORO)
# 725809          2016             NaN  COMMUNITY COLLEGE (QUEENSBORO)
# 1263663         2015             NaN  COMMUNITY COLLEGE (QUEENSBORO)
# 1816444         2014           464.0  COMMUNITY COLLEGE (QUEENSBORO)
# 2305430         2017             NaN  COMMUNITY COLLEGE (QUEENSBORO)
# 2894338         2018           464.0  COMMUNITY COLLEGE (QUEENSBORO)
# 3447047         2019           464.0  COMMUNITY COLLEGE (QUEENSBORO)
#
#         Last Name First Name Mid Init Agency Start Date Work Location Borough  \
# 274009      GREEN      BRUCE        S        11/01/2005                QUEENS
# 725809      GREEN      BRUCE        S        11/01/2005                QUEENS
# 1263663     GREEN      BRUCE        S        11/01/2005                QUEENS
# 1816444     GREEN      BRUCE        S        11/01/2005                   NaN
# ...

# %%
dt[(dt["Last Name"]=="D'AMATO") & (dt["First Name"]=="JEFFREY") & (dt["Agency Name"] =="COMMUNITY COLLEGE (QUEENSBORO)")]
# Out:
#          Fiscal Year  Payroll Number                     Agency Name  \
# 274110          2020           464.0  COMMUNITY COLLEGE (QUEENSBORO)
# 2894365         2018           464.0  COMMUNITY COLLEGE (QUEENSBORO)
# 3447368         2019           464.0  COMMUNITY COLLEGE (QUEENSBORO)
#
#         Last Name First Name Mid Init Agency Start Date Work Location Borough  \
# 274110    D'AMATO    JEFFREY        A        10/09/2017                QUEENS
# 2894365   D'AMATO    JEFFREY        A        10/09/2017                QUEENS
# 3447368   D'AMATO    JEFFREY        A        10/09/2017                QUEENS
#
#         Title Description Leave Status as of June 30  Base Salary  Pay Basis  \
# 274110                NaN                     ACTIVE      64158.0  per Annum
# 2894365               NaN                     ACTIVE      50897.0  per Annum
# 3447368               NaN                     ACTIVE      50897.0  per Annum
#
# ...

# %%
dt[(dt["Last Name"]=="ORTIZ") & (dt["First Name"]=="A") ]
# Out:
#          Fiscal Year  Payroll Number                    Agency Name Last Name  \
# 319029          2020           745.0  DEPT OF ED HRLY SUPPORT STAFF     ORTIZ
# 806136          2016             NaN  DEPT OF ED HRLY SUPPORT STAFF     ORTIZ
# 2383412         2017             NaN  DEPT OF ED HRLY SUPPORT STAFF     ORTIZ
# 3084668         2018           745.0  DEPT OF ED HRLY SUPPORT STAFF     ORTIZ
# 3647711         2019           745.0  DEPT OF ED HRLY SUPPORT STAFF     ORTIZ
#
#         First Name Mid Init Agency Start Date Work Location Borough  \
# 319029           A      NaN        12/31/1999             MANHATTAN
# 806136           A      NaN        12/31/1999             MANHATTAN
# 2383412          A      NaN        12/31/1999             MANHATTAN
# 3084668          A      NaN        12/31/1999             MANHATTAN
# 3647711          A      NaN        12/31/1999             MANHATTAN
#
#         Title Description Leave Status as of June 30  Base Salary Pay Basis  \
# ...

# %% [markdown]
# ok, this didnt work, lets try to find by payroll number

# %%
dt[(dt["Payroll Number"]==464)].head(5)
# Out:
#         Fiscal Year  Payroll Number                     Agency Name Last Name  \
# 273444         2020           464.0  COMMUNITY COLLEGE (QUEENSBORO)     LYNCH
# 273445         2020           464.0  COMMUNITY COLLEGE (QUEENSBORO)   NEWCOMB
# 273446         2020           464.0  COMMUNITY COLLEGE (QUEENSBORO)   CARBONE
# 273447         2020           464.0  COMMUNITY COLLEGE (QUEENSBORO)    DI DIO
# 273448         2020           464.0  COMMUNITY COLLEGE (QUEENSBORO)    PALMER
#
#        First Name Mid Init Agency Start Date Work Location Borough  \
# 273444    TIMOTHY        G        04/04/2017                QUEENS
# 273445     SHERRI        L        09/08/2008                QUEENS
# 273446     JOSEPH      NaN        07/02/1990                QUEENS
# 273447    STEPHEN        M        06/10/2013                QUEENS
# 273448     SANDRA        S        08/25/2015                QUEENS
#
#             Title Description Leave Status as of June 30  Base Salary  \
# ...

# %% [markdown]
# Looks like payroll number is assosciated with agency not title..
#
# Let try by salary and agency for A. Ortiz:

# %%
all_2020[(all_2020["Base Salary"]==16.52) & (all_2020["Agency Name"]=="DEPT OF ED HRLY SUPPORT STAFF")]["Title Description"].value_counts()
# Out:
# F/T SCHOOL AIDE            3319
# F/T SCHOOL LUNCH HELPER    2622
# SUBSTITUTE SCHOOL AIDE       64
# F/T HEALTH SERVICE AIDE      19
# Name: Title Description, dtype: int64

# %% [markdown]
# Seems like this salary is mostly associated with School Aide, I will replace NaN with exatly this title for our active_2020 data.

# %%
all_active_2020.loc[(all_active_2020["Last Name"]=="ORTIZ") & (all_active_2020["First Name"]=="A"), "Title Description" ]= "F/T SCHOOL AIDE"
# Out:
# C:\Users\Maryla\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
all_active_2020[(all_active_2020["Last Name"]=="ORTIZ") & (all_active_2020["First Name"]=="A") ]
# Out:
#         Fiscal Year  Payroll Number                    Agency Name Last Name  \
# 319029         2020           745.0  DEPT OF ED HRLY SUPPORT STAFF     ORTIZ
#
#        First Name Mid Init Agency Start Date Work Location Borough  \
# 319029          A      NaN        12/31/1999             MANHATTAN
#
#        Title Description Leave Status as of June 30  Base Salary Pay Basis  \
# 319029   F/T SCHOOL AIDE                     ACTIVE        16.52  per Hour
#
#         Regular Hours  Regular Gross Paid  OT Hours  Total OT Paid  \
# 319029            0.0             16657.4       0.0            0.0
#
#         Total Other Pay
# 319029          4810.05

# %% [markdown]
# For D'AMATO JEFFREY

# %%
all_2020[(all_2020["Base Salary"]==64158.00)]["Title Description"]
# Out:
# 274110    NaN
# Name: Title Description, dtype: object

# %% [markdown]
# GREEN BRUCE

# %%
all_2020[(all_2020["Base Salary"]==67016.00)]["Title Description"]
# Out:
# 274009    NaN
# Name: Title Description, dtype: object

# %% [markdown]
# Looks like for both GREEN BRUCE, D'AMATO JEFFREY I cannot find Title Desrription..

# %% [markdown]
# ### Let's explore missing values for work location:

# %%
all_active_2020[all_active_2020["Work Location Borough"].isnull()]
# Out:
#         Fiscal Year  Payroll Number                    Agency Name Last Name  \
# 162077         2020           742.0         DEPT OF ED PEDAGOGICAL   COLEMAN
# 419875         2020           744.0  DEPT OF ED PARA PROFESSIONALS    OMOGUN
#
#        First Name Mid Init Agency Start Date Work Location Borough  \
# 162077     KAWANA        D        07/01/1982                   NaN
# 419875       DAYO        O        03/09/1987                   NaN
#
#                 Title Description Leave Status as of June 30  Base Salary  \
# 162077  TEACHER SPECIAL EDUCATION                     ACTIVE     124909.0
# 419875             ANNUAL ED PARA                     ACTIVE      46333.0
#
#         Pay Basis  Regular Hours  Regular Gross Paid  OT Hours  Total OT Paid  \
# 162077  per Annum            0.0           122242.80       0.0            0.0
# 419875  per Annum            0.0            45344.28       0.0            0.0
#
#         Total Other Pay
# 162077         26460.23
# ...

# %% [markdown]
# what is their work history?

# %%
dt[(dt["Last Name"]=="COLEMAN") & (dt["First Name"]=="KAWANA")]
# Out:
#          Fiscal Year  Payroll Number                     Agency Name  \
# 162077          2020           742.0          DEPT OF ED PEDAGOGICAL
# 377343          2020           747.0  DEPT OF ED PER SESSION TEACHER
# 865609          2016             NaN          DEPT OF ED PEDAGOGICAL
# 978698          2016             NaN  DEPT OF ED PER SESSION TEACHER
# 1402126         2015             NaN          DEPT OF ED PEDAGOGICAL
# 1528161         2015             NaN  DEPT OF ED PER SESSION TEACHER
# 1851131         2014           742.0          DEPT OF ED PEDAGOGICAL
# 2015661         2014           747.0  DEPT OF ED PER SESSION TEACHER
# 2443918         2017             NaN          DEPT OF ED PEDAGOGICAL
# 2555466         2017             NaN  DEPT OF ED PER SESSION TEACHER
# 2934859         2018           742.0          DEPT OF ED PEDAGOGICAL
# 3111604         2018           747.0  DEPT OF ED PER SESSION TEACHER
# 3487989         2019           742.0          DEPT OF ED PEDAGOGICAL
# ...

# %% [markdown]
# Looks like this person is working two jobs, one full time teacher and second part time as a session teacher plus looks ike most of the time she is working in Manhattan.

# %%
dt[(dt["Last Name"]=="OMOGUN") & (dt["First Name"]=="DAYO")]
# Out:
#          Fiscal Year  Payroll Number                    Agency Name Last Name  \
# 419875          2020           744.0  DEPT OF ED PARA PROFESSIONALS    OMOGUN
# 835920          2016             NaN  DEPT OF ED PARA PROFESSIONALS    OMOGUN
# 1371713         2015             NaN  DEPT OF ED PARA PROFESSIONALS    OMOGUN
# 1949041         2014           744.0  DEPT OF ED PARA PROFESSIONALS    OMOGUN
# 2413877         2017             NaN  DEPT OF ED PARA PROFESSIONALS    OMOGUN
# 3038084         2018           744.0  DEPT OF ED PARA PROFESSIONALS    OMOGUN
# 3596148         2019           744.0  DEPT OF ED PARA PROFESSIONALS    OMOGUN
#
#         First Name Mid Init Agency Start Date Work Location Borough  \
# 419875        DAYO        O        03/09/1987                   NaN
# 835920        DAYO        O        03/09/1987                   NaN
# 1371713       DAYO        O        03/09/1987                   NaN
# 1949041       DAYO        O        03/09/1987                   NaN
# ...

# %% [markdown]
# Because this didn't give me any answers I googled him and got Manhattan as his work borough
# (https://opengovus.com/new-york-employee/OMOGUN,_NOSAKHARE_I).
#
# I will change for both to be Manhattan.

# %%
indices = [419875, 162077]

# %%
all_active_2020.loc[indices, "Work Location Borough" ] = "MANHATTAN"

# %%
all_active_2020[all_active_2020["Work Location Borough"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Fiscal Year, Payroll Number, Agency Name, Last Name, First Name, Mid Init, Agency Start Date, Work Location Borough, Title Description, Leave Status as of June 30, Base Salary, Pay Basis, Regular Hours, Regular Gross Paid, OT Hours, Total OT Paid, Total Other Pay]
# Index: []

# %% [markdown]
# ok, lets take a look now at all active employess in 2020

# %%
all_active_2020.describe()
# Out:
#        Fiscal Year  Payroll Number    Base Salary  Regular Hours  \
# count     477228.0   477228.000000  477228.000000  477228.000000
# mean        2020.0      556.818739   49462.187477     774.688947
# std            0.0      310.287532   44961.936289     932.368002
# min         2020.0        2.000000       1.000000     -35.000000
# 25%         2020.0      300.000000      33.180000       0.000000
# 50%         2020.0      742.000000   47705.000000       0.000000
# 75%         2020.0      747.000000   85292.000000    1820.000000
# max         2020.0      996.000000  414707.000000    4160.000000
#
#        Regular Gross Paid       OT Hours  Total OT Paid  Total Other Pay
# count       477228.000000  477228.000000  477228.000000    477228.000000
# mean         51452.311863      84.528514    3970.783888      5054.276528
# std          41385.105717     192.514707    9915.350037      6696.435071
# min              0.010000     -21.000000   -2734.970000    -69786.070000
# ...

# %% [markdown]
# some numbers here are a bit disturbing:
#
# - min regular gross paid was 1 cent and base salary was 1 dollar?
# - "total other  pay" being negative number - 69,786?
# - negative overtime?
# - 50% employess dont have any working hours last year, with some having negative work hours

# %% [markdown]
# Let's try to find some answers:

# %% [markdown]
# ## Exploring Working Hours
#
# #### For this I will use all_active_2020 data set

# %%
hours_work_0 = all_active_2020["Regular Hours"].apply(lambda x: True if x <= 0 else False )
len(hours_work_0[hours_work_0 == True])
# Out:
# 266914

# %%
all_active_2020["Regular Hours"].describe()
# Out:
# count    477228.000000
# mean        774.688947
# std         932.368002
# min         -35.000000
# 25%           0.000000
# 50%           0.000000
# 75%        1820.000000
# max        4160.000000
# Name: Regular Hours, dtype: float64

# %%
zero_working_hours = all_active_2020[all_active_2020["Regular Hours"]==0]
negative_working_hours = all_active_2020[all_active_2020["Regular Hours"]<0]
#print(type(zero_working_hours.shape))
print("There was ", zero_working_hours.shape[0], " employees with zero working hours in 2020.")
print("There was ", negative_working_hours.shape[0], " employees with negative working hours in 2020.")
# Out:
# There was  266912  employees with zero working hours in 2020.
# There was  2  employees with negative working hours in 2020.

# %% [markdown]
# what is with negative working hours??

# %%
negative_working_hours
# Out:
#         Fiscal Year  Payroll Number                    Agency Name  \
# 273160         2020           463.0      COMMUNITY COLLEGE (BRONX)
# 295643         2020           469.0  COMMUNITY COLLEGE (LAGUARDIA)
#
#          Last Name First Name Mid Init Agency Start Date  \
# 273160     HASTICK      MAVIS        M        10/23/2004
# 295643  VILLALOBOS   MICHELLE      NaN        09/24/2018
#
#        Work Location Borough             Title Description  \
# 273160                QUEENS             COLLEGE ASSISTANT
# 295643                QUEENS  CONTINUING EDUCATION TEACHER
#
#        Leave Status as of June 30  Base Salary Pay Basis  Regular Hours  \
# 273160                     ACTIVE        23.74  per Hour         -35.00
# 295643                     ACTIVE        56.10  per Hour          -1.75
#
#         Regular Gross Paid  OT Hours  Total OT Paid  Total Other Pay
# 273160               39.18       0.0            0.0              0.0
# ...

# %% [markdown]
# I cannot explain why they would have negative wotking hours...
# These are not a big numbers and I am sure there is an explanations for it!

# %% [markdown]
# What about zero working hours?

# %%
zero_working_hours["Pay Basis"].value_counts(normalize = True)
# Out:
# per Annum          0.453955
# per Day            0.356777
# per Hour           0.189265
# Prorated Annual    0.000004
# Name: Pay Basis, dtype: float64

# %% [markdown]
# Out of 266912 employees with 0 working hours 46% is employed on annual therm  and 54% per hour or per day.

# %% [markdown]
# Let's find out where are these people work and in what titles.
#
# Also did they actually received salary desite having 0 hours entered?

# %%
groupin_0_hours = zero_working_hours.groupby([ "Title Description", "Agency Name"]).agg({"Agency Name":"count", "Base Salary":"mean", "Regular Gross Paid":"mean"})
groupin_0_hours.columns=["Title count", "Avg base salary", "Avg gross paid"]
groupin_0_hours.nlargest(20,"Title count")
# Out:
#                                                              Title count  \
# Title Description            Agency Name
# TEACHER- PER SESSION         DEPT OF ED PER SESSION TEACHER        74004
# TEACHER                      DEPT OF ED PEDAGOGICAL                52249
# ELECTION WORKER              BOARD OF ELECTION POLL WORKERS        30635
# ANNUAL ED PARA               DEPT OF ED PARA PROFESSIONALS         25501
# TEACHER SPECIAL EDUCATION    DEPT OF ED PEDAGOGICAL                24672
# TEACHER-GENERAL ED           DEPT OF ED PER DIEM TEACHERS          10419
# SUBSTITUTE ED PARA           DEPT OF ED PARA PROFESSIONALS          7661
# F/T SCHOOL AIDE              DEPT OF ED HRLY SUPPORT STAFF          7074
# F/T SCHOOL LUNCH HELPER      DEPT OF ED HRLY SUPPORT STAFF          3400
# ASSISTANT PRINCIPAL          DEPT OF ED PEDAGOGICAL                 3323
# GUIDANCE COUNSELOR           DEPT OF ED PEDAGOGICAL                 2934
# ...

# %%
zero_working_hours["Agency Name"].value_counts()
# Out:
# DEPT OF ED PEDAGOGICAL            95468
# DEPT OF ED PER SESSION TEACHER    76353
# DEPT OF ED PARA PROFESSIONALS     33361
# BOARD OF ELECTION POLL WORKERS    30967
# DEPT OF ED HRLY SUPPORT STAFF     17295
# DEPT OF ED PER DIEM TEACHERS      11214
# DOE CUSTODIAL PAYROL               1233
# COMMUNITY COLLEGE (LAGUARDIA)       410
# COMMUNITY COLLEGE (MANHATTAN)       252
# COMMUNITY COLLEGE (HOSTOS)          130
# COMMUNITY COLLEGE (BRONX)            69
# COMMUNITY COLLEGE (KINGSBORO)        64
# COMMUNITY COLLEGE (QUEENSBORO)       46
# GUTTMAN COMMUNITY COLLEGE            44
# HUNTER COLLEGE HIGH SCHOOL            2
# DEPT OF PARKS & RECREATION            2
# DEPARTMENT OF EDUCATION ADMIN         1
# CUNY CENTRAL OFFICE                   1
# Name: Agency Name, dtype: int64

# %% [markdown]
# Lets find out what are the proportions in these aganecies of workers wit zero hours and over zero hours as well as their respective pay basis

# %%
zero_working_agencies = zero_working_hours["Agency Name"].unique()

# %% [markdown]
# ##### agencies_with_zero - data set for all agencies that contain workers with zero hours, including workers that have zero as well as tose who have working hours above zero.

# %%
agencies_with_zero = all_active_2020[all_active_2020["Agency Name"].isin(zero_working_agencies)]

# make a new column with indication if employee worked 0 hours or over zero.
agencies_with_zero["Hours Count"]= agencies_with_zero["Regular Hours"].apply(lambda x: "zero" if x==0 else "over zero")
# Out:
# C:\Users\Maryla\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
cross_tab_zero_hours = pd.crosstab(agencies_with_zero["Pay Basis"], agencies_with_zero["Hours Count"])
cross_tab_zero_hours
# Out:
# Hours Count      over zero    zero
# Pay Basis
# Prorated Annual       1089       1
# per Annum            22072  121166
# per Day               1940   95228
# per Hour             10625   50517

# %%
cross_tab_zero_hours.plot.barh()
plt.show()

# %% [markdown]
# which agencies have only employees with zero hours?

# %%
pd.crosstab(agencies_with_zero["Agency Name"], agencies_with_zero["Hours Count"])
# Out:
# Hours Count                     over zero   zero
# Agency Name
# BOARD OF ELECTION POLL WORKERS          0  30967
# COMMUNITY COLLEGE (BRONX)            1636     69
# COMMUNITY COLLEGE (HOSTOS)           1331    130
# COMMUNITY COLLEGE (KINGSBORO)        2232     64
# COMMUNITY COLLEGE (LAGUARDIA)        2779    410
# COMMUNITY COLLEGE (MANHATTAN)        3063    252
# COMMUNITY COLLEGE (QUEENSBORO)       1978     46
# CUNY CENTRAL OFFICE                   119      1
# DEPARTMENT OF EDUCATION ADMIN       13714      1
# DEPT OF ED HRLY SUPPORT STAFF           0  17295
# DEPT OF ED PARA PROFESSIONALS           0  33361
# DEPT OF ED PEDAGOGICAL                  0  95468
# DEPT OF ED PER DIEM TEACHERS            0  11214
# DEPT OF ED PER SESSION TEACHER          0  76353
# DEPT OF PARKS & RECREATION           8181      2
# DOE CUSTODIAL PAYROL                    0   1233
# GUTTMAN COMMUNITY COLLEGE             456     44
# HUNTER COLLEGE HIGH SCHOOL            237      2

# %%
cross_tab_agencies_pay_basis_vs_hours = agencies_with_zero.groupby(["Agency Name", "Pay Basis", "Hours Count"]).agg({"Agency Name":"count"})
cross_tab_agencies_pay_basis_vs_hours
# Out:
#                                                             Agency Name
# Agency Name                    Pay Basis       Hours Count
# BOARD OF ELECTION POLL WORKERS per Hour        zero               30967
# COMMUNITY COLLEGE (BRONX)      per Annum       over zero            810
#                                per Day         over zero            146
#                                per Hour        over zero            680
#                                                zero                  69
# COMMUNITY COLLEGE (HOSTOS)     per Annum       over zero            599
#                                per Day         over zero            109
#                                per Hour        over zero            623
#                                                zero                 130
# COMMUNITY COLLEGE (KINGSBORO)  per Annum       over zero            858
#                                per Day         over zero            287
# ...

# %%
agencies_with_zero[(agencies_with_zero["Pay Basis"] =="per Annum") & (agencies_with_zero["Hours Count"] == "zero")]['Agency Name'].value_counts()
# Out:
# DEPT OF ED PEDAGOGICAL           95468
# DEPT OF ED PARA PROFESSIONALS    25698
# Name: Agency Name, dtype: int64

# %% [markdown]
# These are only two agancies where employment is based on annual salary and where working hours are not counted, it make some sensein this case.
# What about other employees whos salary is based on how much they actualy worked and who acctually receved a salary..??

# %%
agencies_with_zero[((agencies_with_zero["Pay Basis"] =="per Hour") | (agencies_with_zero["Pay Basis"] =="per Day")) & (agencies_with_zero["Hours Count"] == "zero") & (agencies_with_zero['Regular Gross Paid']>0)]['Agency Name'].value_counts()
# Out:
# DEPT OF ED PER SESSION TEACHER    76353
# BOARD OF ELECTION POLL WORKERS    30967
# DEPT OF ED HRLY SUPPORT STAFF     17295
# DEPT OF ED PER DIEM TEACHERS      11214
# DEPT OF ED PARA PROFESSIONALS      7663
# DOE CUSTODIAL PAYROL               1233
# COMMUNITY COLLEGE (LAGUARDIA)       410
# COMMUNITY COLLEGE (MANHATTAN)       252
# COMMUNITY COLLEGE (HOSTOS)          130
# COMMUNITY COLLEGE (BRONX)            69
# COMMUNITY COLLEGE (KINGSBORO)        64
# COMMUNITY COLLEGE (QUEENSBORO)       46
# GUTTMAN COMMUNITY COLLEGE            44
# DEPT OF PARKS & RECREATION            2
# HUNTER COLLEGE HIGH SCHOOL            2
# CUNY CENTRAL OFFICE                   1
# Name: Agency Name, dtype: int64

# %% [markdown]
# WOW! Looks like they did make some earnings but no hours entered. I am guessing this is some kind of data omission.
#
# Let's just see a sample of this data:

# %%
agencies_with_zero[((agencies_with_zero["Pay Basis"] =="per Hour") | (agencies_with_zero["Pay Basis"] =="per Day")) & (agencies_with_zero["Hours Count"] == "zero") & (agencies_with_zero['Regular Gross Paid']>0)].head(10)
# Out:
#        Fiscal Year  Payroll Number                     Agency Name  \
# 6600          2020           300.0  BOARD OF ELECTION POLL WORKERS
# 6895          2020           300.0  BOARD OF ELECTION POLL WORKERS
# 10512         2020           300.0  BOARD OF ELECTION POLL WORKERS
# 11223         2020           300.0  BOARD OF ELECTION POLL WORKERS
# 31868         2020           300.0  BOARD OF ELECTION POLL WORKERS
# 33588         2020           300.0  BOARD OF ELECTION POLL WORKERS
# 73544         2020           300.0  BOARD OF ELECTION POLL WORKERS
# 75563         2020           300.0  BOARD OF ELECTION POLL WORKERS
# 75635         2020           300.0  BOARD OF ELECTION POLL WORKERS
# 80127         2020           300.0  BOARD OF ELECTION POLL WORKERS
#
#         Last Name First Name Mid Init Agency Start Date Work Location Borough  \
# 6600     BLANFORD     DONALD        C        01/01/2019             MANHATTAN
# ...

# %%
zero_hours_get_paid = agencies_with_zero[((agencies_with_zero["Pay Basis"] =="per Hour") | (agencies_with_zero["Pay Basis"] =="per Day")) & (agencies_with_zero["Hours Count"] == "zero") & (agencies_with_zero['Regular Gross Paid']>0)]
zero_hours_get_paid["Regular Gross Paid"].value_counts(normalize = True)
# Out:
# 350.00      0.054053
# 600.00      0.030739
# 250.00      0.019074
# 255.65      0.011753
# 603.00      0.010868
#               ...
# 6029.40     0.000007
# 25576.74    0.000007
# 3204.98     0.000007
# 20241.62    0.000007
# 23243.95    0.000007
# Name: Regular Gross Paid, Length: 78417, dtype: float64

# %%
plt.hist (zero_hours_get_paid["Regular Gross Paid"], bins = 50)
plt.show()

# %% [markdown]
# Looks like majority of daily and hourly employees is making below 25,000 a year.
# 50% of them made 350 dollars in 2020, in what title?

# %%
zero_hours_get_paid[zero_hours_get_paid["Regular Gross Paid"] ==350]["Title Description"].value_counts()
# Out:
# ELECTION WORKER     7876
# ELECTION TRAINER       2
# Name: Title Description, dtype: int64

# %% [markdown]
# In 2020 we had 7,876 election workers who made 350 dollars -we just dont know how may hours/ days they were working

# %% [markdown]
# Who are the top earners with 0 working hours ?

# %%
zero_hours_get_paid.groupby(["Title Description", "Pay Basis"]).agg({"Regular Gross Paid":"mean", "Base Salary":"mean"}).nlargest(50, "Base Salary")
# Out:
#                                                 Regular Gross Paid  \
# Title Description                    Pay Basis
# CUSTODIAN ENGINEER                   per Hour         92293.492887
# PRINCIPAL                            per Day          29235.860588
# ASSISTANT PRINCIPAL                  per Day          24981.850000
# SUPERVISOR                           per Day          25164.701319
# SCHOOL SOCIAL WORKER                 per Day          19130.883611
# SCHOOL PSYCHOLOGIST                  per Day          16608.031569
# TEACHER-SPECIAL ED                   per Day          18339.662973
# GUIDANCE COUNSELOR                   per Day          20313.952458
# SECRETARY                            per Day          14866.516914
# LAB SPECIALIST/ASSISTANT             per Day          21158.530000
# SUBSTITUTE ED PARA                   per Day          14455.102733
# TEACHER-GENERAL ED                   per Day          13001.678151
# ...

# %% [markdown]
# Lookls like there might be a mistake with the "CUSTODIAN ENGINEER" job desription. I think it is ment to be annual salary. I check online and this job is usually paid per annum:
# (https://www1.nyc.gov/assets/dcas/downloads/pdf/noes/201909013000.pdf)

# %% [markdown]
# I will check for this title against the whole data

# %%
dt[dt["Title Description"]==   "CUSTODIAN ENGINEER"]["Pay Basis"].value_counts()
# Out:
# per Hour    8065
# Name: Pay Basis, dtype: int64

# %%
dt[dt["Title Description"]==   "CUSTODIAN ENGINEER"]["Base Salary"].value_counts()
# Out:
# 1.00         4643
# 136060.23     343
# 126971.41     291
# 145968.23     134
# 103742.58      75
#              ...
# 73150.55        1
# 134325.09       1
# 143209.12       1
# 100397.76       1
# 84911.63        1
# Name: Base Salary, Length: 349, dtype: int64

# %% [markdown]
# I will change Pay Basis description for this particular title in all_active_2020 !

# %%
all_active_2020.loc[all_active_2020["Title Description"] =="CUSTODIAN ENGINEER", "Pay Basis"]="per Annum"

# %% [markdown]
# Now lets remove "per Anum" form 'zero_hours_get_paid':

# %%
custodian = zero_hours_get_paid[zero_hours_get_paid["Title Description"] =="CUSTODIAN ENGINEER"].index
custodian
# Out:
# Int64Index([127777, 127778, 127779, 127780, 127781, 127782, 127783, 127784,
#             127785, 127786,
#             ...
#             129189, 129190, 129191, 129192, 129193, 129194, 129197, 129198,
#             129207, 129210],
#            dtype='int64', length=1233)

# %%
zero_hours_get_paid.drop(custodian, inplace =True)
# Out:
# C:\Users\Maryla\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# Let's explore per Hour group:

# %%
plt.hist (zero_hours_get_paid[zero_hours_get_paid["Pay Basis"]=='per Hour'] ["Base Salary"], bins = 20)
plt.show()

# %%
zero_hours_get_paid[zero_hours_get_paid["Pay Basis"]=='per Hour']["Base Salary"].describe()
# Out:
# count    49284.000000
# mean         7.070624
# std          8.722489
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%         16.520000
# max        111.610000
# Name: Base Salary, dtype: float64

# %% [markdown]
# The smallest hourly base salaries are:

# %%
zero_hours_get_paid[zero_hours_get_paid["Pay Basis"]=='per Hour'].groupby(["Title Description"]).agg({'Title Description':"count", "Regular Gross Paid":"mean", "Base Salary":"mean"}).nsmallest(3, "Base Salary")
# Out:
#                                 Title Description  Regular Gross Paid  \
# Title Description
# ELECTION TRAINER                              332         5703.787229
# ELECTION WORKER                             30635          813.953105
# SUBSTITUTE SCHOOL LUNCH HELPER                287         5515.355226
#
#                                 Base Salary
# Title Description
# ELECTION TRAINER                   1.000000
# ELECTION WORKER                    1.010021
# SUBSTITUTE SCHOOL LUNCH HELPER    14.370000

# %% [markdown]
# The bggest hourly salaries are:

# %%
zero_hours_get_paid[zero_hours_get_paid["Pay Basis"]=='per Hour'].groupby(["Title Description"]).agg({'Title Description':"count", "Regular Gross Paid":"mean", "Base Salary":"mean"}).nlargest(5, "Base Salary")
# Out:
#                              Title Description  Regular Gross Paid  \
# Title Description
# PROFESSOR                                    5           44.900000
# ADJUNCT ASSOCIATE PROFESSOR                  2          160.575000
# ASSOCIATE PROFESSOR                          6           23.990000
# ADJUNCT ASSISTANT PROFESSOR                 18           90.465556
# ASSISTANT PROFESSOR                          3            4.403333
#
#                              Base Salary
# Title Description
# PROFESSOR                     103.482000
# ADJUNCT ASSOCIATE PROFESSOR   101.345000
# ASSOCIATE PROFESSOR            95.110000
# ADJUNCT ASSISTANT PROFESSOR    86.796111
# ASSISTANT PROFESSOR            85.603333

# %% [markdown]
# Who is the highest paid in hourly group:

# %%
max_hourly= zero_hours_get_paid[zero_hours_get_paid["Pay Basis"]=='per Hour']["Base Salary"].max()
zero_hours_get_paid[zero_hours_get_paid["Base Salary"] == max_hourly]
# Out:
#         Fiscal Year  Payroll Number                    Agency Name  \
# 295047         2020           469.0  COMMUNITY COLLEGE (LAGUARDIA)
# 295431         2020           469.0  COMMUNITY COLLEGE (LAGUARDIA)
#
#          Last Name First Name Mid Init Agency Start Date  \
# 295047  SANCHIRICO      SUSAN        M        09/20/1993
# 295431      NIEMAN      JAIME      NaN        09/01/1991
#
#        Work Location Borough            Title Description  \
# 295047                QUEENS  ADJUNCT ASSOCIATE PROFESSOR
# 295431                QUEENS          ASSOCIATE PROFESSOR
#
#        Leave Status as of June 30  Base Salary Pay Basis  Regular Hours  \
# 295047                     ACTIVE       111.61  per Hour            0.0
# 295431                     ACTIVE       111.61  per Hour            0.0
#
#         Regular Gross Paid  OT Hours  Total OT Paid  Total Other Pay  \
# 295047              174.15       0.0            0.0              0.0
# ...

# %% [markdown]
# Who, out of all per hour employees, made the most in 2020.

# %%
max_pay_hourly= zero_hours_get_paid[zero_hours_get_paid["Pay Basis"]=='per Hour']["Regular Gross Paid"].max()
zero_hours_get_paid[zero_hours_get_paid["Regular Gross Paid"] == max_pay_hourly]
# Out:
#         Fiscal Year  Payroll Number                    Agency Name  Last Name  \
# 461174         2020           745.0  DEPT OF ED HRLY SUPPORT STAFF  FRATIANNI
#
#        First Name Mid Init Agency Start Date Work Location Borough  \
# 461174    MARYANN        C        04/27/1999             MANHATTAN
#
#        Title Description Leave Status as of June 30  Base Salary Pay Basis  \
# 461174   F/T SCHOOL AIDE                     ACTIVE         17.0  per Hour
#
#         Regular Hours  Regular Gross Paid  OT Hours  Total OT Paid  \
# 461174            0.0             75040.0       0.0            0.0
#
#         Total Other Pay Hours Count
# 461174          4252.12        zero

# %% [markdown]
# ##### Let's explore per day group

# %%
plt.hist (zero_hours_get_paid[zero_hours_get_paid["Pay Basis"]=='per Day'] ["Base Salary"], bins = 20)
plt.show()

# %%
zero_hours_get_paid[zero_hours_get_paid["Pay Basis"]=='per Day']["Base Salary"].describe()
# Out:
# count    95228.000000
# mean        57.056064
# std         59.985650
# min          1.000000
# 25%         33.180000
# 50%         33.180000
# 75%         33.180000
# max        920.990000
# Name: Base Salary, dtype: float64

# %% [markdown]
# The smallest daily base salaries are:

# %%
zero_hours_get_paid[zero_hours_get_paid["Pay Basis"]=='per Day'].groupby(["Title Description"]).agg({'Title Description':"count", "Regular Gross Paid":"mean", "Base Salary":"mean"}).nsmallest(5, "Base Salary")
# Out:
#                               Title Description  Regular Gross Paid  \
# Title Description
# SCHOOL SECRETARY PER SESSION               1301         3661.772629
# TEACHER- PER SESSION                      74004         3812.523746
# SUPERVISOR PER SESSION                     1048         3804.222948
# TEACHER-GENERAL ED                        10419        13001.678151
# SUBSTITUTE ED PARA                         7661        14455.102733
#
#                               Base Salary
# Title Description
# SCHOOL SECRETARY PER SESSION    20.450000
# TEACHER- PER SESSION            33.247556
# SUPERVISOR PER SESSION          34.780000
# TEACHER-GENERAL ED             129.940808
# SUBSTITUTE ED PARA             161.740500

# %% [markdown]
# The biggest daily base salaries are:

# %%
zero_hours_get_paid[zero_hours_get_paid["Pay Basis"]=='per Day'].groupby(["Title Description"]).agg({'Title Description':"count", "Regular Gross Paid":"mean", "Base Salary":"mean"}).nlargest(5, "Base Salary")
# Out:
#                       Title Description  Regular Gross Paid  Base Salary
# Title Description
# PRINCIPAL                            17        29235.860588   860.452941
# ASSISTANT PRINCIPAL                  83        24981.850000   643.703133
# SUPERVISOR                           91        25164.701319   641.129560
# SCHOOL SOCIAL WORKER                 36        19130.883611   357.178333
# SCHOOL PSYCHOLOGIST                  51        16608.031569   353.999216

# %% [markdown]
# Who, out of daily employees made the most in 2020?

# %%
max_pay_hourly= zero_hours_get_paid[zero_hours_get_paid["Pay Basis"]=='per Day']["Regular Gross Paid"].max()
zero_hours_get_paid[zero_hours_get_paid["Regular Gross Paid"] == max_pay_hourly]
# Out:
#         Fiscal Year  Payroll Number                     Agency Name Last Name  \
# 340309         2020           747.0  DEPT OF ED PER SESSION TEACHER     MEYER
#
#        First Name Mid Init Agency Start Date Work Location Borough  \
# 340309     ELIANE      NaN        09/07/1983             MANHATTAN
#
#            Title Description Leave Status as of June 30  Base Salary  \
# 340309  TEACHER- PER SESSION                     ACTIVE        33.18
#
#        Pay Basis  Regular Hours  Regular Gross Paid  OT Hours  Total OT Paid  \
# 340309   per Day            0.0           107761.77       0.0            0.0
#
#         Total Other Pay Hours Count
# 340309         13450.24        zero

# %% [markdown]
# ## Exploring  Base Salary:
# This data can be skewed by the fact that some salaries are entered as annual and some as hourly or daily. To get accurate stat I need to separate these entries.
# ### I think that for accuracy sake this data should be separated while working on salaries

# %% [markdown]
# ##### Now  let's see why some salaries are as low as $1

# %%
all_active_2020['Pay Basis'].unique()
# Out:
# array(['per Annum', 'per Hour', 'Prorated Annual', 'per Day'],
#       dtype=object)

# %%
all_active_2020['Pay Basis'].value_counts(normalize = True)
# Out:
# per Annum          0.631847
# per Day            0.220905
# per Hour           0.143799
# Prorated Annual    0.003449
# Name: Pay Basis, dtype: float64

# %%
annual_2020 = all_active_2020[(all_active_2020['Pay Basis'] == 'per Annum' ) | (all_active_2020['Pay Basis'] == 'Prorated Annual' )]

# %%
daily_2020 = all_active_2020[all_active_2020['Pay Basis'] == 'per Day']
hourly_2020 = all_active_2020[all_active_2020['Pay Basis'] == 'per Hour']

# %% [markdown]
# #### Exploring annual salaries

# %%
annual_2020["Base Salary"].describe()
# Out:
# count    303181.000000
# mean      77824.572530
# std       31247.411493
# min           1.000000
# 25%       50604.000000
# 50%       77318.000000
# 75%       97428.000000
# max      414707.000000
# Name: Base Salary, dtype: float64

# %% [markdown]
# annual salary of 1 dollar, that is odd!!

# %%
annual_2020[annual_2020["Base Salary"]== 1]
# Out:
#         Fiscal Year  Payroll Number           Agency Name     Last Name  \
# 128254         2020           202.0  DOE CUSTODIAL PAYROL        ROSADO
# 128601         2020           202.0  DOE CUSTODIAL PAYROL         VELEZ
# 128608         2020           202.0  DOE CUSTODIAL PAYROL       JIMENEZ
# 128609         2020           202.0  DOE CUSTODIAL PAYROL         BEARD
# 128614         2020           202.0  DOE CUSTODIAL PAYROL       CARROLL
# ...             ...             ...                   ...           ...
# 129194         2020           202.0  DOE CUSTODIAL PAYROL        PARETI
# 129197         2020           202.0  DOE CUSTODIAL PAYROL       GALLARO
# 129198         2020           202.0  DOE CUSTODIAL PAYROL      MCCAULEY
# 129207         2020           202.0  DOE CUSTODIAL PAYROL      SCHEMBRI
# 129210         2020           202.0  DOE CUSTODIAL PAYROL  MCGRAW JR JR
#
#        First Name Mid Init Agency Start Date Work Location Borough  \
# ...

# %%
annual_2020[annual_2020["Base Salary"]<10000].nsmallest(15,"Base Salary")
# Out:
#         Fiscal Year  Payroll Number            Agency Name        Last Name  \
# 124752         2020           102.0           CITY COUNCIL            MYEKU
# 124681         2020           102.0           CITY COUNCIL           MCGHIE
# 124682         2020           102.0           CITY COUNCIL        STRADFORD
# 124780         2020           102.0           CITY COUNCIL             FUDA
# 124670         2020           102.0           CITY COUNCIL             CHAN
# 124698         2020           102.0           CITY COUNCIL         SEINFELD
# 124700         2020           102.0           CITY COUNCIL          GEREMIA
# 124787         2020           102.0           CITY COUNCIL          DISCALA
# 546477         2020           996.0  NYC HOUSING AUTHORITY          JOHNSON
# 124667         2020           102.0           CITY COUNCIL  MERCADO VASQUEZ
# 546277         2020           996.0  NYC HOUSING AUTHORITY            ADAMS
# ...

# %% [markdown]
# Looks like what is making the numbers jump from 3,000 to 400,000 might have to do do with some people working part time.

# %%
annual_2020[annual_2020["Regular Hours"]>4000]
# Out:
#         Fiscal Year  Payroll Number               Agency Name Last Name  \
# 110775         2020            72.0  DEPARTMENT OF CORRECTION   JOHNSON
#
#        First Name Mid Init Agency Start Date Work Location Borough  \
# 110775      DAVID      NaN        05/26/2011                QUEENS
#
#          Title Description Leave Status as of June 30  Base Salary  Pay Basis  \
# 110775  CORRECTION OFFICER                     ACTIVE      85292.0  per Annum
#
#         Regular Hours  Regular Gross Paid  OT Hours  Total OT Paid  \
# 110775         4160.0           169314.96     584.5       20853.77
#
#         Total Other Pay
# 110775         30833.61

# %% [markdown]
# #### hmm either their is a typo or this guy worked litteraly double shift every single day....How is it possible?

# %% [markdown]
# .

# %% [markdown]
# ### Regular full time is between 30 and 40 hours a week, meaning full time a year is between 1560 and 1820 hours. I will create new column and assign employees either being full time or part time.

# %%
annual_2020["Working Time"]= annual_2020["Regular Hours"].apply(lambda x: "FULL TIME" if x>=1560 else( "PART TIME" if x>0 else "NOT Applicable" ))
annual_2020.head(30)
# Out:
# C:\Users\Maryla\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     Fiscal Year  Payroll Number                     Agency Name  \
# 0          2020            17.0  OFFICE OF EMERGENCY MANAGEMENT
# 1          2020            17.0  OFFICE OF EMERGENCY MANAGEMENT
# 2          2020            17.0  OFFICE OF EMERGENCY MANAGEMENT
# 3          2020            17.0  OFFICE OF EMERGENCY MANAGEMENT
# 4          2020            17.0  OFFICE OF EMERGENCY MANAGEMENT
# 5          2020            17.0  OFFICE OF EMERGENCY MANAGEMENT
# 6          2020            17.0  OFFICE OF EMERGENCY MANAGEMENT
# ...

# %%
annual_2020["Working Time"].value_counts()
# Out:
# FULL TIME         165683
# NOT Applicable    121167
# PART TIME          15098
# Name: Working Time, dtype: int64

# %%
annual_2020.describe()
# Out:
#        Fiscal Year  Payroll Number    Base Salary  Regular Hours  \
# count     301948.0   301948.000000  301948.000000  301948.000000
# mean        2020.0      512.099719   77841.008489    1116.078188
# std            0.0      345.020029   31091.388387     951.000580
# min         2020.0        2.000000    3912.000000       0.000000
# 25%         2020.0       67.000000   50604.000000       0.000000
# 50%         2020.0      742.000000   77318.000000    1820.000000
# 75%         2020.0      744.000000   97324.000000    2080.000000
# max         2020.0      996.000000  414707.000000    4160.000000
#
#        Regular Gross Paid       OT Hours  Total OT Paid  Total Other Pay
# count       301948.000000  301948.000000  301948.000000    301948.000000
# mean         74071.832370     122.762307    5510.069625      7188.564802
# std          31589.701366     220.885874   10686.956000      7050.446958
# min              4.590000     -21.000000   -2734.970000    -69786.070000
# ...

# %% [markdown]
# On average base salary for city worker in 2020 was 77,318.00 dollars.

# %% [markdown]
# max: 414,707.00
# min: 3,912 - I guess some part timer?

# %% [markdown]
# 50% of city employess earned between 50,604 and 97,324.
# Top 25% between 97,824 and 414,707 dollars.

# %%
dt["Work Location Borough"].unique()
# Out:
# array(['BROOKLYN', 'MANHATTAN', 'BRONX', 'RICHMOND', 'QUEENS',
#        'WASHINGTON DC', 'ULSTER', 'WESTCHESTER', 'OTHER', 'ALBANY',
#        'NASSAU', 'DELAWARE', 'SULLIVAN', nan, 'ORANGE', 'SCHOHARIE',
#        'DUTCHESS', 'GREENE', 'PUTNAM', 'Bronx', 'Queens', 'Richmond',
#        'Manhattan'], dtype=object)

# %%
annual_2020['Agency Name'].unique()
# Out:
# array(['OFFICE OF EMERGENCY MANAGEMENT', 'OFFICE OF MANAGEMENT & BUDGET',
#        'TAX COMMISSION', 'LAW DEPARTMENT', 'DEPARTMENT OF CITY PLANNING',
#        'DEPARTMENT OF INVESTIGATION', 'TEACHERS RETIREMENT SYSTEM',
#        'CIVILIAN COMPLAINT REVIEW BD', 'POLICE DEPARTMENT',
#        'FIRE DEPARTMENT', "NYC DEPT OF VETERANS' SERVICES",
#        "ADMIN FOR CHILDREN'S SVCS", 'HRA/DEPT OF SOCIAL SERVICES',
#        'DEPT. OF HOMELESS SERVICES', 'DEPARTMENT OF CORRECTION',
#        'BOARD OF CORRECTION', 'MAYORS OFFICE OF CONTRACT SVCS',
#        'PUBLIC ADVOCATE', 'CITY COUNCIL', 'CITY CLERK',
#        'DEPARTMENT FOR THE AGING', 'CULTURAL AFFAIRS',
#        'FINANCIAL INFO SVCS AGENCY', 'OFF OF PAYROLL ADMINISTRATION',
#        'INDEPENDENT BUDGET OFFICE', 'EQUAL EMPLOY PRACTICES COMM',
#        'CIVIL SERVICE COMMISSION', 'LANDMARKS PRESERVATION COMM',
#        'TAXI & LIMOUSINE COMMISSION', 'MUNICIPAL WATER FIN AUTHORITY',
# ...

# %%
may_off=all_2020[(all_2020["Agency Name"]=="MAYORS OFFICE OF CONTRACT SVCS") & (all_2020['Title Description'] == "RESEARCH PROJECTS COORD") & (all_2020["Leave Status as of June 30"] == "ACTIVE")]

# %% [markdown]
# .

# %% [markdown]
# #### 1. Who is person with the most ovetime hours in 2020

# %%
all_2020[all_2020['OT Hours'] == all_2020['OT Hours'].max()]
# Out:
#         Fiscal Year  Payroll Number               Agency Name Last Name  \
# 110727         2020            72.0  DEPARTMENT OF CORRECTION   MALCOLM
#
#        First Name Mid Init Agency Start Date Work Location Borough  \
# 110727       OMAR        T        09/06/2012                QUEENS
#
#                                    Title Description  \
# 110727  WARDEN-ASSISTANT DEPUTY WARDEN TED < 11/1/92
#
#        Leave Status as of June 30  Base Salary  Pay Basis  Regular Hours  \
# 110727                     ACTIVE     111142.0  per Annum         2080.0
#
#         Regular Gross Paid  OT Hours  Total OT Paid  Total Other Pay
# 110727           110385.63    3147.0      127375.43          13559.4

# %% [markdown]
# #### 2. Who is person with the most overtime pay in 2020?

# %%
max_pay= all_2020['Total OT Paid'].max()
all_2020[all_2020['Total OT Paid'] == max_pay ]
# Out:
#         Fiscal Year  Payroll Number            Agency Name Last Name  \
# 534090         2020           996.0  NYC HOUSING AUTHORITY   PROCIDA
#
#        First Name Mid Init Agency Start Date Work Location Borough  \
# 534090     ROBERT      NaN        04/13/1987                 BRONX
#
#          Title Description Leave Status as of June 30  Base Salary Pay Basis  \
# 534090  SUPERVISOR PLUMBER                     ACTIVE       387.03   per Day
#
#         Regular Hours  Regular Gross Paid  OT Hours  Total OT Paid  \
# 534090         1820.0            100627.8    1944.5      215022.81
#
#         Total Other Pay
# 534090          6468.93

# %% [markdown]
# #### 3 . Top 5 agencies with the most OT hours in 2020

# %%
overtime_2020 = all_2020.groupby("Agency Name").agg({'Total OT Paid': "sum", "OT Hours":'sum'})

overtime_2020.nlargest(5, 'OT Hours')
# Out:
#                           Total OT Paid     OT Hours
# Agency Name
# POLICE DEPARTMENT          8.131975e+08  17773758.86
# FIRE DEPARTMENT            3.336954e+08   7597977.43
# DEPARTMENT OF CORRECTION   1.500708e+08   3600418.52
# NYC HOUSING AUTHORITY      1.383776e+08   2636670.00
# DEPARTMENT OF SANITATION   1.518302e+08   2564212.57

# %% [markdown]
# ##### average cost of overtime pay per hour

# %%
overtime_2020["OT per hour"] = overtime_2020["Total OT Paid"]/overtime_2020['OT Hours']

overtime_2020.nlargest(5, "OT per hour")
# Out:
#                                 Total OT Paid    OT Hours  OT per hour
# Agency Name
# CITY CLERK                              12.05        0.00          inf
# TAX COMMISSION                      118053.11     1686.00    70.019638
# CAMPAIGN FINANCE BOARD              377466.64     5898.80    63.990412
# DEPT OF ENVIRONMENT PROTECTION    50538858.92   824528.38    61.294262
# DEPARTMENT OF TRANSPORTATION      62930011.27  1028060.52    61.212361

# %% [markdown]
# There is a misteke in data entry, how somone with 0 overtime hours can be paid..

# %%
all_2020[all_2020["Agency Name"]=="CITY CLERK"]
# Out:
#         Fiscal Year  Payroll Number Agency Name  Last Name First Name  \
# 124821         2020           103.0  CITY CLERK  MCSWEENEY    MICHAEL
# 124822         2020           103.0  CITY CLERK   MICHALOS   EMMANUEL
# 124823         2020           103.0  CITY CLERK    FUENTES      ALISA
# 124824         2020           103.0  CITY CLERK     ACOSTA    DAMARIS
# 124825         2020           103.0  CITY CLERK    SYNMOIE    PATRICK
# ...             ...             ...         ...        ...        ...
# 124900         2020           103.0  CITY CLERK      BURKE     SOPHIE
# 124901         2020           103.0  CITY CLERK    LIANDER    MICHAEL
# 124902         2020           103.0  CITY CLERK    MENDOZA      SUSEJ
# 124903         2020           103.0  CITY CLERK    ARYAKIA      ROBIN
# 124904         2020           103.0  CITY CLERK   HEDGPETH     DENNIS
#
#        Mid Init Agency Start Date Work Location Borough  \
# 124821        M        01/26/2004             MANHATTAN
# ...

# %% [markdown]
# Let's explore this?

# %%
all_2020[(all_2020["Total OT Paid"]>0) & (all_2020["OT Hours"]==0) ].count()
# Out:
# Fiscal Year                   4876
# Payroll Number                4876
# Agency Name                   4876
# Last Name                     4874
# First Name                    4874
# Mid Init                      2850
# Agency Start Date             4876
# Work Location Borough         4876
# Title Description             4875
# Leave Status as of June 30    4876
# Base Salary                   4876
# Pay Basis                     4876
# Regular Hours                 4876
# Regular Gross Paid            4876
# OT Hours                      4876
# Total OT Paid                 4876
# Total Other Pay               4876
# dtype: int64

# %%
all_2020[(all_2020["Total OT Paid"]>0) & (all_2020["OT Hours"]==0) ]
# Out:
#         Fiscal Year  Payroll Number                     Agency Name  \
# 121            2020            17.0  OFFICE OF EMERGENCY MANAGEMENT
# 1478           2020            25.0                  LAW DEPARTMENT
# 1867           2020            25.0                  LAW DEPARTMENT
# 2083           2020            25.0                  LAW DEPARTMENT
# 2624           2020            25.0                  LAW DEPARTMENT
# ...             ...             ...                             ...
# 548000         2020           996.0           NYC HOUSING AUTHORITY
# 548001         2020           996.0           NYC HOUSING AUTHORITY
# 548002         2020           996.0           NYC HOUSING AUTHORITY
# 548003         2020           996.0           NYC HOUSING AUTHORITY
# 548004         2020           996.0           NYC HOUSING AUTHORITY
#
#             Last Name First Name Mid Init Agency Start Date  \
# 121               LIU    JEFFREY        C        02/16/2016
# ...

# %%
all_2020[(all_2020["Total OT Paid"]>0) & (all_2020["OT Hours"]==0) ]
# Out:
#         Fiscal Year  Payroll Number                     Agency Name  \
# 121            2020            17.0  OFFICE OF EMERGENCY MANAGEMENT
# 1478           2020            25.0                  LAW DEPARTMENT
# 1867           2020            25.0                  LAW DEPARTMENT
# 2083           2020            25.0                  LAW DEPARTMENT
# 2624           2020            25.0                  LAW DEPARTMENT
# ...             ...             ...                             ...
# 548000         2020           996.0           NYC HOUSING AUTHORITY
# 548001         2020           996.0           NYC HOUSING AUTHORITY
# 548002         2020           996.0           NYC HOUSING AUTHORITY
# 548003         2020           996.0           NYC HOUSING AUTHORITY
# 548004         2020           996.0           NYC HOUSING AUTHORITY
#
#             Last Name First Name Mid Init Agency Start Date  \
# 121               LIU    JEFFREY        C        02/16/2016
# ...

# %% [markdown]
# ####  4. which agency has the most employees and which one the least?

# %% [markdown]
# for this question lets use data for all employees for fiscal year 2020 including those paid by day or hour

# %%
all_2020.groupby('Agency Name').size().nlargest(5)
# Out:
# Agency Name
# DEPT OF ED PEDAGOGICAL            114999
# DEPT OF ED PER SESSION TEACHER    105717
# POLICE DEPARTMENT                  60316
# DEPT OF ED PARA PROFESSIONALS      41353
# BOARD OF ELECTION POLL WORKERS     31026
# dtype: int64

# %%
all_2020.groupby('Agency Name').size().nsmallest(5)
# Out:
# Agency Name
# DEPARTMENT OF JUVENILE JUSTICE    1
# BRONX COMMUNITY BOARD #1          2
# BRONX COMMUNITY BOARD #12         2
# BRONX COMMUNITY BOARD #3          2
# BROOKLYN COMMUNITY BOARD #8       2
# dtype: int64

# %%
all_2020.groupby(['Agency Name','Pay Basis']).agg({'Agency Name':"count"}).nlargest(6, "Agency Name")
# Out:
#                                           Agency Name
# Agency Name                    Pay Basis
# DEPT OF ED PEDAGOGICAL         per Annum       114999
# DEPT OF ED PER SESSION TEACHER per Day         105717
# POLICE DEPARTMENT              per Annum        56182
# DEPT OF ED PARA PROFESSIONALS  per Annum        32370
# BOARD OF ELECTION POLL WORKERS per Hour         31026
# DEPT OF ED HRLY SUPPORT STAFF  per Hour         21373

# %% [markdown]
# #### looks like the agency with the most employees hired on annual basis is Department of Education: 14,999, while the agency with the most per hour workers is Board of Election.

# %% [markdown]
# ### 5. which agency has the biggest overall salary budget?

# %%
all_2020.groupby("Agency Name").agg({'Regular Gross Paid':"sum"}).nlargest(10,'Regular Gross Paid' )
# Out:
#                                 Regular Gross Paid
# Agency Name
# DEPT OF ED PEDAGOGICAL                8.941733e+09
# POLICE DEPARTMENT                     3.904777e+09
# FIRE DEPARTMENT                       1.313839e+09
# DEPT OF ED PARA PROFESSIONALS         1.081775e+09
# DEPARTMENT OF EDUCATION ADMIN         9.655585e+08
# DEPARTMENT OF CORRECTION              8.362346e+08
# DEPARTMENT OF SANITATION              7.545331e+08
# HRA/DEPT OF SOCIAL SERVICES           7.367492e+08
# NYC HOUSING AUTHORITY                 6.823752e+08
# DEPT OF ENVIRONMENT PROTECTION        5.069852e+08

# %% [markdown]
# ### 6 . In 2020 what was an average annual salary for higest paid job titles?

# %%
annual_2020.groupby("Title Description").agg({"Base Salary":"mean"}).nlargest(25, "Base Salary")
# Out:
#                                                       Base Salary
# Title Description
# CHANCELLOR                                          363346.000000
# PENSION INVESTMENT ADVISOR                          350000.000000
# CHIEF ACTUARY                                       311885.000000
# FIRST DEPUTY MAYOR                                  291139.000000
# CHAIR                                               283900.250000
# MAYOR                                               258750.000000
# DIRECTOR OF  INVESTMENTS                            251758.500000
# DEPUTY MAYOR                                        250758.833333
# FIRST ASSISTANT CORPORATION COUNSEL                 243272.000000
# CHIEF CITY MEDICAL EXAMINER                         243171.000000
# COMMISSIONER OF BUILDINGS                           243171.000000
# COMMISSIONER OF CHILDREN'S SERVICES                 243171.000000
# COMMISSIONER OF CITYWIDE ADMINISTRATIVE SERVICES    243171.000000
# ...

# %%
annual_2020.groupby("Title Description").agg({"Base Salary":"mean"}).nsmallest(25, "Base Salary")
# Out:
#                                        Base Salary
# Title Description
# SUMMER COLLEGE INTERN                 20922.500000
# TEACHER ASSISTANT - REG SUB           24056.400000
# CITY SECURITY AIDE                    27040.400000
# COMMUNITY SERVICE AIDE                27394.436090
# TEACHER AIDE                          28001.078947
# ASSISTANT TEACHER                     29632.909091
# TEMPORARY CLERK                       29965.833333
# COLLEGE AIDE                          29988.000000
# CITY SEASONAL AIDE                    30377.052023
# FINGERPRINT TECHNICIAN TRAINEE        30435.400000
# ASSISTANT MEDIA SERVICES TECHNICAN    31827.500000
# SCHOOL LUNCH AIDE                     32454.229551
# QUALITY ASSURANCE SPECIALIST TRAINEE  32705.187500
# CAMPUS SECURITY ASSISTANT             32932.716418
# EMERGENCY MEDICAL SPECIALIST TRAINEE  32934.888889
# SCHOOL CROSSING GUARD                 34630.695652
# CUNY CUSTODIAL ASSISTANT              34880.231454
# ...

# %%
annual_2020.groupby("Title Description").agg({"Base Salary":["min","max", "mean"]})
# Out:
#                                         Base Salary
#                                                 min       max           mean
# Title Description
# *ADM SCHOOL SECURITY MANAGER-U              73068.0   85725.0   82560.750000
# *ADMIN SCHL SECUR MGR-MGL                  185587.0  185587.0  185587.000000
# *ADMINISTRATIVE ATTORNEY                   135883.0  228341.0  173727.333333
# *AGENCY ATTORNEY                           110848.0  135679.0  123306.250000
# *ASIST SYSTMS ANALYST                       73482.0   73482.0   73482.000000
# ...                                             ...       ...            ...
# WIPER                                       88400.0   88400.0   88400.000000
# WORKER'S COMPENSATION BENEFITS EXAMINER     41388.0   64928.0   51531.942857
# X-RAY TECHNICIAN                            49021.0   69481.0   59340.416667
# YOUTH COORDINATOR                           58741.0   60855.0   59994.750000
# ...

# %% [markdown]
# #### 50 most common titles in the city system

# %%
all_2020['Title Description'].value_counts().nlargest(50)
# Out:
# TEACHER- PER SESSION                               103246
# TEACHER                                             63626
# ANNUAL ED PARA                                      32146
# ELECTION WORKER                                     30685
# TEACHER SPECIAL EDUCATION                           28976
# POLICE OFFICER                                      24835
# TEACHER-GENERAL ED                                  10525
# CORRECTION OFFICER                                   9434
# FIREFIGHTER                                          9085
# SUBSTITUTE ED PARA                                   8786
# F/T SCHOOL AIDE                                      8287
# COLLEGE ASSISTANT                                    6972
# SANITATION WORKER                                    6865
# COMMUNITY ASSOCIATE                                  6197
# JOB TRAINING PARTICIPANT                             6021
# SCHOOL SAFETY AGENT                                  5910
# ...

# %%
g
